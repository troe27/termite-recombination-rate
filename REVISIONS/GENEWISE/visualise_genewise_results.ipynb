# %%
# imports
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
s_ex = pd.read_csv('source_exons.txt', sep=' ', header=None)

# %%
gw_ex = pd.read_csv('genewise_predicted_exons.gff3', sep='\t', header=None)

# %%
gw_ex.columns = ['scaffold','origin' , 'kind', 'start','end', 'NA1', 'strand', 'NA2', 'IDstring']

# %%
gw_ex[['scaffold', 'kind', 'start', 'end', 'strand']].iloc[2:,]
# Out:
#                                           scaffold    kind  start    end  \
# 2   scaffold42_9663171_f40Z9663171:3910516-3945151   match      9  25941
# 3   scaffold42_9663171_f40Z9663171:3910516-3945151     cds      9    120
# 4   scaffold42_9663171_f40Z9663171:3910516-3945151  intron    121   1741
# 5   scaffold42_9663171_f40Z9663171:3910516-3945151     cds   1742   1872
# 6   scaffold42_9663171_f40Z9663171:3910516-3945151  intron   1873   3836
# 7   scaffold42_9663171_f40Z9663171:3910516-3945151     cds   3837   3934
# 8   scaffold42_9663171_f40Z9663171:3910516-3945151  intron   3935   6440
# 9   scaffold42_9663171_f40Z9663171:3910516-3945151     cds   6441   6517
# 10  scaffold42_9663171_f40Z9663171:3910516-3945151  intron   6518   7358
# 11  scaffold42_9663171_f40Z9663171:3910516-3945151     cds   7359   7469
# 12  scaffold42_9663171_f40Z9663171:3910516-3945151  intron   7470   9011
# 13  scaffold42_9663171_f40Z9663171:3910516-3945151     cds   9012   9088
# ...

# %%
s_ex
# Out:
#               0      1      2
# 0  source_Exons      1    112
# 1  source_Exons   1734   1864
# 2  source_Exons   3829   3926
# 3  source_Exons   6433   6509
# 4  source_Exons   7351   7461
# 5  source_Exons   9004   9080
# 6  source_Exons  10200  10391
# 7  source_Exons  15407  15668
# 8  source_Exons  24504  24777
# 9  source_Exons  25561  25933

# %%
gff_ss = gw_ex

# %%
txv=True


text_kwargs = dict(ha='center', va='center', fontsize=12, color='firebrick')

fig, ax3 = plt.subplots(ncols=1, nrows=1, figsize=(20,2))
for i,k in gff_ss.iterrows():
    if k.kind=="match":
        #print(k.start)
        #print(k.end)
        ax3.hlines(0, k.start, k.end, lw=1, color='black', zorder=-400)
        #GID = k.IDstring.split(";")[-2].split("=")[1]
        #plt.text( np.mean([k.start, k.end]), 0.5, GID, **text_kwargs)
    elif k.kind=="cds":
        #print(k)
        #print(k.start, k.end)
        #tx_v = k.IDstring.split(";")[-2].split(" ")[-1]
        ax3.hlines(0, k.start, k.end, lw=10, color='grey', zorder=-300, label='predicted exons')
        ax3.hlines(0, k.start, k.start+5, lw=10, color='black', zorder=100)
        ax3.hlines(0, k.end, k.end+5, lw=10, color='black', zorder=100)

for i,k in s_ex.iterrows():
     
        ax3.hlines(-1, k[1], k[2], lw=10, color='orange', zorder=-300, label=' mapped source exons')
ax3.hlines(-1, s_ex[1].min(), s_ex[2].max(), lw=1, color='orange', zorder=-400)

        #ax3.hlines(-1,  k[1],  k[1]+5, lw=10, color='black', zorder=100)
        #ax3.hlines(-1, k[2], k[2]+5, lw=10, color='black', zorder=100)

ax3.hlines(0, 7358, 7471, lw=10, color='firebrick', zorder=300)
plt.text( np.mean([7358, 7471]),1, 'SSXRD', **text_kwargs)




text_kwargs = dict(ha='center', va='center', fontsize=12, color='indigo')

for i,k in pr_set_df.iterrows():
    if k.kind=="cds":
        ax3.hlines(0, k.start, k.end, lw=10, color='indigo', zorder=-300)
        ax3.hlines(0, pr_set_df.start.min(), pr_set_df.end.max(), lw=10, color='indigo', zorder=-300, alpha=0.1)

plt.text( np.mean([pr_set_df.start.min(), pr_set_df.end.max()]),1, 'PR/SET', **text_kwargs)

text_kwargs = dict(ha='center', va='center', fontsize=12, color='seagreen')
for i,k in zf1_df.iterrows():
    if k.kind=="cds":
        ax3.hlines(0, k.start, k.end, lw=10, color='seagreen', zorder=-300)
   
        ax3.hlines(0, zf1_df.start.min(), zf1_df.end.max(), lw=10, color='seagreen', zorder=-300, alpha=0.1)

plt.text( np.mean([zf1_df.start.min(), zf1_df.end.max()]),1, 'ZF1', **text_kwargs)


text_kwargs = dict(ha='center', va='center', fontsize=12, color='coral')
for i,k in zf2_df.iterrows():
    if k.kind=="cds":
        ax3.hlines(0, k.start, k.end, lw=10, color='coral', zorder=-300)
        ax3.hlines(0, zf2_df.start.min(), zf2_df.end.max(), lw=10, color='coral', zorder=-300, alpha=0.1)

plt.text( np.mean([zf2_df.start.min(), zf2_df.end.max()]),1.8, 'ZF2', **text_kwargs)



text_kwargs = dict(ha='center', va='center', fontsize=12, color='teal')
for i,k in krab_df.iterrows():
    if k.kind=="cds":
        ax3.hlines(0, k.start, k.end, lw=10, color='teal', zorder=-300)
        ax3.hlines(0, krab_df.start.min(), krab_df.end.max(), lw=10, color='teal', zorder=-300, alpha=0.1)

        #ax3.hlines(-2, k.end, k.end+5, lw=10, color='black', zorder=100)
plt.text( np.mean([krab_df.start.min(), krab_df.end.max()]),1, 'KRAB', **text_kwargs)

#ax3.hlines(-2, k.start, k.end, lw=0, color='white', zorder=-500, label='conserved protein domains')


handles, labels = plt.gca().get_legend_handles_labels()
newLabels, newHandles = [], []
for handle, label in zip(handles, labels):
  if label not in newLabels:
    newLabels.append(label)
    newHandles.append(handle)
plt.legend(newHandles, newLabels, loc=(0.96,0.34))


ax3.set_ylim(-4, 3)
plt.tight_layout()
sns.despine( bottom=True, left=True)
plt.xticks([0,25000])
ax3.set_xticklabels(['3912328', '3937328'])
ax3.set_yticks([])
ax3.set_xlabel('Scaffold42 , position in basepairs')
plt.savefig('genewise_PRDM9_rev_Mbel.png')
plt.savefig('genewise_PRDM9_rev_Mbel.pdf')

plt.show()

# %%
SSXRD = ["SSXRD", 7358,7471]

# %%
3910516+1812
# Out:
# 3912328

# %%
3910516+1812+25000
# Out:
# 3937328

# %%
string_gff = """scaffold42_9663171_f40Z9663171:3910516-3945151	GeneWise	match	9014	15633	288.04	+	.	scaffold42_9663171_f40Z9663171:3910516-3945151-genewise-prediction-1
scaffold42_9663171_f40Z9663171:3910516-3945151	GeneWise	cds	9014	9088	0.00	+	0	scaffold42_9663171_f40Z9663171:3910516-3945151-genewise-prediction-1
scaffold42_9663171_f40Z9663171:3910516-3945151	GeneWise	intron	9089	10207	0.00	+	.	scaffold42_9663171_f40Z9663171:3910516-3945151-genewise-prediction-1
scaffold42_9663171_f40Z9663171:3910516-3945151	GeneWise	cds	10208	10399	0.00	+	0	scaffold42_9663171_f40Z9663171:3910516-3945151-genewise-prediction-1
scaffold42_9663171_f40Z9663171:3910516-3945151	GeneWise	intron	10400	15414	0.00	+	.	scaffold42_9663171_f40Z9663171:3910516-3945151-genewise-prediction-1
scaffold42_9663171_f40Z9663171:3910516-3945151	GeneWise	cds	15415	15633	0.00	+	0	scaffold42_9663171_f40Z9663171:3910516-3945151-genewise-prediction-1"""

df = pd.DataFrame([i.split('\t') for i in string_gff.split('\n')])
df.columns = ['scaffold','origin' , 'kind', 'start','end', 'NA1', 'strand', 'NA2', 'IDstring']
df.start = df.start.astype(int)
df.end = df.end.astype(int)
pr_set_df = df

# %%
pr_set_df
# Out:
#                                          scaffold    origin    kind  start  \
# 0  scaffold42_9663171_f40Z9663171:3910516-3945151  GeneWise   match   9014
# 1  scaffold42_9663171_f40Z9663171:3910516-3945151  GeneWise     cds   9014
# 2  scaffold42_9663171_f40Z9663171:3910516-3945151  GeneWise  intron   9089
# 3  scaffold42_9663171_f40Z9663171:3910516-3945151  GeneWise     cds  10208
# 4  scaffold42_9663171_f40Z9663171:3910516-3945151  GeneWise  intron  10400
# 5  scaffold42_9663171_f40Z9663171:3910516-3945151  GeneWise     cds  15415
#
#      end     NA1 strand NA2                                           IDstring
# 0  15633  288.04      +   .  scaffold42_9663171_f40Z9663171:3910516-3945151...
# 1   9088    0.00      +   0  scaffold42_9663171_f40Z9663171:3910516-3945151...
# 2  10207    0.00      +   .  scaffold42_9663171_f40Z9663171:3910516-3945151...
# 3  10399    0.00      +   0  scaffold42_9663171_f40Z9663171:3910516-3945151...
# ...

# %%
string_gff = '''scaffold42_9663171_f40Z9663171:3910516-3945151	GeneWise	match	25765	25848	29.49	+	.	scaffold42_9663171_f40Z9663171:3910516-3945151-genewise-prediction-1
scaffold42_9663171_f40Z9663171:3910516-3945151	GeneWise	cds	25765	25848	0.00	+	0	scaffold42_9663171_f40Z9663171:3910516-3945151-genewise-prediction-1'''

df = pd.DataFrame([i.split('\t') for i in string_gff.split('\n')])
df.columns = ['scaffold','origin' , 'kind', 'start','end', 'NA1', 'strand', 'NA2', 'IDstring']
df.start = df.start.astype(int)
df.end = df.end.astype(int)
zf2_df = df

# %%
string_gff = '''scaffold42_9663171_f40Z9663171:3910516-3945151	GeneWise	match	25681	25764	34.47	+	.	scaffold42_9663171_f40Z9663171:3910516-3945151-genewise-prediction-1
scaffold42_9663171_f40Z9663171:3910516-3945151	GeneWise	cds	25681	25764	0.00	+	0	scaffold42_9663171_f40Z9663171:3910516-3945151-genewise-prediction-1'''

df = pd.DataFrame([i.split('\t') for i in string_gff.split('\n')])
df.columns = ['scaffold','origin' , 'kind', 'start','end', 'NA1', 'strand', 'NA2', 'IDstring']
df.start = df.start.astype(int)
df.end = df.end.astype(int)
zf1_df = df

# %%
string_gff = '''scaffold42_9663171_f40Z9663171:3910516-3945151	GeneWise	match	6	1812	63.31	+	.	scaffold42_9663171_f40Z9663171:3910516-3945151-genewise-prediction-1
scaffold42_9663171_f40Z9663171:3910516-3945151	GeneWise	cds	6	120	0.00	+	0	scaffold42_9663171_f40Z9663171:3910516-3945151-genewise-prediction-1
scaffold42_9663171_f40Z9663171:3910516-3945151	GeneWise	intron	121	1741	0.00	+	.	scaffold42_9663171_f40Z9663171:3910516-3945151-genewise-prediction-1
scaffold42_9663171_f40Z9663171:3910516-3945151	GeneWise	cds	1742	1812	0.00	+	2	scaffold42_9663171_f40Z9663171:3910516-3945151-genewise-prediction-1'''

df = pd.DataFrame([i.split('\t') for i in string_gff.split('\n')])
df.columns = ['scaffold','origin' , 'kind', 'start','end', 'NA1', 'strand', 'NA2', 'IDstring']
df.start = df.start.astype(int)
df.end = df.end.astype(int)
krab_df = df

# %%
krab_df
# Out:
#                                          scaffold    origin    kind  start  \
# 0  scaffold42_9663171_f40Z9663171:3910516-3945151  GeneWise   match      6
# 1  scaffold42_9663171_f40Z9663171:3910516-3945151  GeneWise     cds      6
# 2  scaffold42_9663171_f40Z9663171:3910516-3945151  GeneWise  intron    121
# 3  scaffold42_9663171_f40Z9663171:3910516-3945151  GeneWise     cds   1742
#
#     end    NA1 strand NA2                                           IDstring
# 0  1812  63.31      +   .  scaffold42_9663171_f40Z9663171:3910516-3945151...
# 1   120   0.00      +   0  scaffold42_9663171_f40Z9663171:3910516-3945151...
# 2  1741   0.00      +   .  scaffold42_9663171_f40Z9663171:3910516-3945151...
# 3  1812   0.00      +   2  scaffold42_9663171_f40Z9663171:3910516-3945151...

# %%
# import csec_gff
gff_path = "/home/tilman/termites/gene_density/Csec/GCF_002891405.2_Csec_1.0_genomic_with_introns.gff"
csec_gff = pd.read_csv(gff_path, sep='\t', header=None, comment="#")

# %%
csec_gff.loc[csec_gff[2].isin(["gene","exon" ])]
# Out:
#                      0       1     2     3      4  5  6  7  \
# 1       NW_019718022.1  Gnomon  gene   753  65939  .  -  .
# 3       NW_019718022.1  Gnomon  exon   753    844  .  -  .
# 6       NW_019718022.1  Gnomon  exon  1842   2146  .  -  .
# 9       NW_019718022.1  Gnomon  exon  3613   3705  .  -  .
# 12      NW_019718022.1  Gnomon  exon  6034   6150  .  -  .
# ...                ...     ...   ...   ...    ... .. .. ..
# 966018  NW_019773506.1  Gnomon  exon     7    336  .  +  .
# 966020  NW_019773506.1  Gnomon  exon   702    943  .  +  .
# 966022  NW_019773507.1  Gnomon  gene   823   1401  .  +  .
# 966024  NW_019773507.1  Gnomon  exon   823    975  .  +  .
# 966026  NW_019773507.1  Gnomon  exon  1096   1401  .  +  .
#
#                                                         8
# 1       ID=gene-LOC111862762;Dbxref=GeneID:111862762;N...
# 3       ID=exon-XM_023849672.2-9;Parent=rna-XM_0238496...
# 6       ID=exon-XM_023849672.2-8;Parent=rna-XM_0238496...
# ...

# %%
csec_gff.loc[csec_gff[2].isin(["exon" ])][8].iloc[0,]
# Out:
# 'ID=exon-XM_023849672.2-9;Parent=rna-XM_023849672.2;Dbxref=GeneID:111862762,Genbank:XM_023849672.2;Note=The sequence of the model RefSeq transcript was modified relative to this genomic sequence to represent the inferred CDS: added 2707 bases not found in genome assembly;exception=annotated by transcript or proteomic data;gbkey=mRNA;gene=LOC111862762;inference=similar to RNA sequence (same species):INSD:GHZM01222878.1;partial=true;product=uncharacterized LOC111862762%2C transcript variant X2;start_range=.,753;transcript_id=XM_023849672.2'

# %%
dbx_ids = []
for i, k in csec_gff.iterrows():
    seight = k[8].split(";")
    dbx_id = [i for i in seight if i.startswith("Dbxref")] 
    
    if len(dbx_id)<1:
        dbx_ids.append(k[8])
    else:
        dbx_ids.append(dbx_id[0].split("=")[1])
        #dbx_id = [i for i in seight if i.startswith("Dbxref")] #[0].split("=")[1]
    #dbx_ids.append(dbx_id[0])

# %%
csec_gff["dbx"] = dbx_ids

# %%
LOC111864767

# %%
PRDM9_gff = []
for i,k in csec_gff.loc[csec_gff[2].isin(["gene", "exon"])].iterrows():
    if k["dbx"].startswith("GeneID:111864767"):
        PRDM9_gff.append(k)

# %%
csec_prdm9 = pd.DataFrame(PRDM9_gff)

# %%
csec_prdm9
# Out:
#                     0       1     2       3       4  5  6  7  \
# 34405  NW_019719366.1  Gnomon  gene  304604  325449  .  -  .
# 34407  NW_019719366.1  Gnomon  exon  304604  307167  .  -  .
# 34410  NW_019719366.1  Gnomon  exon  309483  309744  .  -  .
# 34413  NW_019719366.1  Gnomon  exon  315124  315315  .  -  .
# 34416  NW_019719366.1  Gnomon  exon  316106  316182  .  -  .
# 34419  NW_019719366.1  Gnomon  exon  319167  319277  .  -  .
# 34422  NW_019719366.1  Gnomon  exon  319915  319991  .  -  .
# 34425  NW_019719366.1  Gnomon  exon  322482  322579  .  -  .
# 34428  NW_019719366.1  Gnomon  exon  324271  324401  .  -  .
# 34432  NW_019719366.1  Gnomon  exon  325029  325449  .  -  .
#
#                                                        8  \
# 34405  ID=gene-LOC111864767;Dbxref=GeneID:111864767;N...
# 34407  ID=exon-XM_023852281.2-9;Parent=rna-XM_0238522...
# 34410  ID=exon-XM_023852281.2-8;Parent=rna-XM_0238522...
# 34413  ID=exon-XM_023852281.2-7;Parent=rna-XM_0238522...
# ...

# %%
txv=True


text_kwargs = dict(ha='center', va='center', fontsize=12, color='firebrick')

fig, ax3 = plt.subplots(ncols=1, nrows=1, figsize=(20,2))
for i,k in csec_prdm9.iterrows():
    if k[2]=="gene":
        #print(k.start)
        #print(k.end)
        ax3.hlines(0, k[4], k[3], lw=1, color='black', zorder=-400)
    elif k[2]=="exon":
        #print(k)
        #print(k.start, k.end)
        #tx_v = k.IDstring.split(";")[-2].split(" ")[-1]
        ax3.hlines(0, k[4], k[3], lw=10, color='grey', zorder=-300, label='predicted exons')
        #ax3.hlines(0, k[3], k[4]+5, lw=10, color='black', zorder=100)
        #ax3.hlines(0, k[3], k[4]+5, lw=10, color='black', zorder=100)


ax3.set_ylim(-4, 3)
plt.tight_layout()
sns.despine( bottom=True, left=True)
#plt.xticks([0,25000])
#ax3.set_xticklabels(['3912328', '3937328'])
ax3.set_yticks([])
#ax3.set_xlabel('Scaffold42 , position in basepairs')
#plt.savefig('genewise_PRDM9_rev.png')
#plt.savefig('genewise_PRDM9_rev.pdf')

plt.show()

# %%
string_gff = """NW_019719366.1:c325449-304604	GeneWise	match	6172	6285	81.05	+	.	NW_019719366.1:c325449-304604-genewise-prediction-1
NW_019719366.1:c325449-304604	GeneWise	cds	6172	6285	0.00	+	0	NW_019719366.1:c325449-304604-genewise-prediction-1"""

df = pd.DataFrame([i.split('\t') for i in string_gff.split('\n')])
df.columns = ['scaffold','origin' , 'kind', 'start','end', 'NA1', 'strand', 'NA2', 'IDstring']
df.start = df.start.astype(int)
df.end = df.end.astype(int)
csec_SSXRD_df = df

# %%
string_gff = """NW_019719366.1:c325449-304604	GeneWise	match	9270	15924	350.49	+	.	NW_019719366.1:c325449-304604-genewise-prediction-1
NW_019719366.1:c325449-304604	GeneWise	cds	9270	9344	0.00	+	0	NW_019719366.1:c325449-304604-genewise-prediction-1
NW_019719366.1:c325449-304604	GeneWise	intron	9345	10134	0.00	+	.	NW_019719366.1:c325449-304604-genewise-prediction-1
NW_019719366.1:c325449-304604	GeneWise	cds	10135	10326	0.00	+	0	NW_019719366.1:c325449-304604-genewise-prediction-1
NW_019719366.1:c325449-304604	GeneWise	intron	10327	15705	0.00	+	.	NW_019719366.1:c325449-304604-genewise-prediction-1
NW_019719366.1:c325449-304604	GeneWise	cds	15706	15924	0.00	+	0	NW_019719366.1:c325449-304604-genewise-prediction-1"""

df = pd.DataFrame([i.split('\t') for i in string_gff.split('\n')])
df.columns = ['scaffold','origin' , 'kind', 'start','end', 'NA1', 'strand', 'NA2', 'IDstring']
df.start = df.start.astype(int)
df.end = df.end.astype(int)
csec_pr_set_df = df

# %%
string_gff = """NW_019719366.1:c325449-304604	GeneWise	match	18747	18830	62.96	+	.	NW_019719366.1:c325449-304604-genewise-prediction-1
NW_019719366.1:c325449-304604	GeneWise	cds	18747	18830	0.00	+	0	NW_019719366.1:c325449-304604-genewise-prediction-1"""

df = pd.DataFrame([i.split('\t') for i in string_gff.split('\n')])
df.columns = ['scaffold','origin' , 'kind', 'start','end', 'NA1', 'strand', 'NA2', 'IDstring']
df.start = df.start.astype(int)
df.end = df.end.astype(int)
csec_zf1_df = df

# %%
string_gff = """NW_019719366.1:c325449-304604	GeneWise	match	18831	18914	61.96	+	.	NW_019719366.1:c325449-304604-genewise-prediction-1
NW_019719366.1:c325449-304604	GeneWise	cds	18831	18914	0.00	+	0	NW_019719366.1:c325449-304604-genewise-prediction-1"""
df = pd.DataFrame([i.split('\t') for i in string_gff.split('\n')])
df.columns = ['scaffold','origin' , 'kind', 'start','end', 'NA1', 'strand', 'NA2', 'IDstring']
df.start = df.start.astype(int)
df.end = df.end.astype(int)
csec_zf2_df = df

# %%
string_gff = """NW_019719366.1:c325449-304604	GeneWise	match	295	1119	120.99	+	.	NW_019719366.1:c325449-304604-genewise-prediction-1
NW_019719366.1:c325449-304604	GeneWise	cds	295	421	0.00	+	0	NW_019719366.1:c325449-304604-genewise-prediction-1
NW_019719366.1:c325449-304604	GeneWise	intron	422	1048	0.00	+	.	NW_019719366.1:c325449-304604-genewise-prediction-1
NW_019719366.1:c325449-304604	GeneWise	cds	1049	1119	0.00	+	2	NW_019719366.1:c325449-304604-genewise-prediction-1 """
df = pd.DataFrame([i.split('\t') for i in string_gff.split('\n')])
df.columns = ['scaffold','origin' , 'kind', 'start','end', 'NA1', 'strand', 'NA2', 'IDstring']
df.start = df.start.astype(int)
df.end = df.end.astype(int)
csec_krab_df = df

# %%
txv=True



fig, ax3 = plt.subplots(ncols=1, nrows=1, figsize=(20,2))
for i,k in csec_prdm9.iterrows():
    if k[2]=="gene":
        #print(k.start)
        #print(k.end)
        ax3.hlines(0, k[3], k[4], lw=1, color='black', zorder=-400)
    elif k[2]=="exon":
        #print(k)
        #print(k.start, k.end)
        #tx_v = k.IDstring.split(";")[-2].split(" ")[-1]
        ax3.hlines(0, k[3], k[4], lw=10, color='grey', zorder=-300, label='predicted exons')
        #ax3.hlines(0, k[3], k[4]+5, lw=10, color='black', zorder=100)
        #ax3.hlines(0, k[3], k[4]+5, lw=10, color='black', zorder=100)

        #ax3.hlines(-1,  k[1],  k[1]+5, lw=10, color='black', zorder=100)
       #ax3.hlines(-1, k[2], k[2]+5, lw=10, color='black', zorder=100)



text_kwargs = dict(ha='center', va='center', fontsize=12, color='firebrick')
ax3.hlines(0, 325449-6172,325449-6285, lw=10, color='firebrick', zorder=300)
plt.text( np.mean([325449-6172,325449-6285]),-1.3, 'SSXRD', **text_kwargs)




text_kwargs = dict(ha='center', va='center', fontsize=12, color='indigo')

for i,k in csec_pr_set_df.iterrows():
    if k.kind=="cds":
        ax3.hlines(0, 325449-k.start, 325449-k.end, lw=10, color='indigo', zorder=-300)
        ax3.hlines(0, 309743, 316179, lw=10, color='indigo', zorder=-300, alpha=0.1)

#309743 316179
        #ax3.hlines(-2, (325449-pr_set_df.start).min(), (325449-pr_set_df.end).max(), lw=10, color='indigo', zorder=-300, alpha=0.1)

plt.text( np.mean([325449-pr_set_df.start.min(), 325449-pr_set_df.end.max()]),-1.3, 'PR/SET', **text_kwargs)

text_kwargs = dict(ha='center', va='center', fontsize=12, color='seagreen')
for i,k in csec_zf1_df.iterrows():
    if k.kind=="cds":
        ax3.hlines(0, 325449-k.start, 325449-k.end, lw=10, color='seagreen', zorder=-300)
   
        #ax3.hlines(-2, 325449-zf1_df.start.min(), 325449-zf1_df.end.max(), lw=10, color='seagreen', zorder=-300, alpha=0.1)

plt.text( np.mean([325449-k.start, 325449-k.end]),-1, 'ZF1', **text_kwargs)


text_kwargs = dict(ha='center', va='center', fontsize=12, color='coral')
for i,k in csec_zf2_df.iterrows():
    if k.kind=="cds":
        ax3.hlines(0, 325449-k.start, 325449-k.end, lw=10, color='coral', zorder=-300)
        #ax3.hlines(-2, 325449-zf2_df.start.min(), 325449-zf2_df.end.max(), lw=10, color='coral', zorder=-300, alpha=0.1)

plt.text( np.mean([325449-k.start, 325449-k.end]),-1.8, 'ZF2', **text_kwargs)



text_kwargs = dict(ha='center', va='center', fontsize=12, color='teal')
for i,k in csec_krab_df.iterrows():
    if k.kind=="cds":
        ax3.hlines(0, 325449-k.start, 325449-k.end, lw=10, color='teal', zorder=-300)
       # ax3.hlines(-2, 325449-krab_df.start.max(), 325449-krab_df.end.min(), lw=10, color='teal', zorder=-300, alpha=0.1)
        ax3.hlines(0, 324400, 325028, lw=10, color='teal', zorder=-300, alpha=0.1)

        #ax3.hlines(-2, k.end, k.end+5, lw=10, color='black', zorder=100)
plt.text( np.mean([325449-krab_df.start.min(), 325449-krab_df.end.max()]),-1.3, 'KRAB', **text_kwargs)

#ax3.hlines(-2, 325449-k.start, 325449-k.end, lw=0, color='white', zorder=-500, label='conserved protein domains')


handles, labels = plt.gca().get_legend_handles_labels()
newLabels, newHandles = [], []
for handle, label in zip(handles, labels):
  if label not in newLabels:
    newLabels.append(label)
    newHandles.append(handle)
#plt.legend(newHandles, newLabels, loc=(0.96,0.2))


ax3.set_ylim(-2, 2)
plt.tight_layout()
sns.despine( bottom=True, left=True)
#plt.xticks([0,25000])
#ax3.set_xticklabels(['3912328', '3937328'])
ax3.set_yticks([])
#ax3.set_yticks([])
plt.tight_layout()
ax3.set_xlabel('NW_019719366.1 , position in basepairs')
plt.savefig('genewise_PRDM9_rev_csec.png',bbox_inches='tight')
plt.savefig('genewise_PRDM9_rev_csec.pdf',bbox_inches='tight')

plt.show()

# %%
(325449-csec_krab_df.end).max()
# Out:
# 325028

# %%
(325449-csec_krab_df.start).min()
# Out:
# 324400

# %%
csec_krab_df
# Out:
#                         scaffold    origin    kind  start   end     NA1  \
# 0  NW_019719366.1:c325449-304604  GeneWise   match    295  1119  120.99
# 1  NW_019719366.1:c325449-304604  GeneWise     cds    295   421    0.00
# 2  NW_019719366.1:c325449-304604  GeneWise  intron    422  1048    0.00
# 3  NW_019719366.1:c325449-304604  GeneWise     cds   1049  1119    0.00
#
#   strand NA2                                           IDstring
# 0      +   .  NW_019719366.1:c325449-304604-genewise-predict...
# 1      +   0  NW_019719366.1:c325449-304604-genewise-predict...
# 2      +   .  NW_019719366.1:c325449-304604-genewise-predict...
# 3      +   2  NW_019719366.1:c325449-304604-genewise-predict...
