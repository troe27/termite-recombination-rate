# %%
import pandas as pd
import numpy as np
import os
import subprocess

# %%
import argparse

# %%
def create_and_submit_sbatch(batch, chunk):
    name="RHO_Csec_gene_batch{batch}.job".format(batch=batch)
    sbatch = [ "#!/bin/bash -l",
                    "#SBATCH -A naiss2023-22-450",
                    "#SBATCH -t 2:0:0 ",
                    "#SBATCH -p core -n 1",
                    "#SBATCH -J {name}".format(name=name),
                    "#SBATCH -o {name}_%j.out".format(name=name),
                    "#SBATCH -e {name}_%j.error".format(name=name),
                    "#SBATCH --get-user-env",
                    "##command underneath this##",
                    "conda activate base",
                    "python csec_get_intron_mean.py --genelist {chunk} --batchname {batch}".format(chunk=chunk, batch=batch)]
    with open(name, 'wt') as handle:
        handle.write("\n".join(sbatch))
    subprocess.call(["chmod", "766", name])
    subprocess.call(["sbatch", name])

# %%
Csec_rho_gene_and_flank = pd.read_csv('./Csec/20230919_Csec_rho_per_gene_and_50kbflank_with_10kbbuffer_newfilt.tsv', sep='\t')
Csec_rho_exon_and_intron = pd.read_csv('/proj/snic2021-23-365/private/TR_20230707/TR_20230707_per_gene_analysis/Csec/old_data/rho_per_gene/20230717_Csec_rho_exons_and_introns.tsv', sep='\t', index_col=0)
Csec_rho_exon_and_intron.columns = ['scaffold', 'source', 'featuretype', 'start', 'stop', 'n', 'strand', 'n2', 'ID', 'scaffold_alt', 'rho']
        #CpG
Csec_CpG_gene_and_flank = pd.read_csv( './Csec/old_data/20230810_Csec_CpG_per_gene_and_50kbflank_10kbbuffer.tsv', sep='\t', index_col=0)
Csec_CpG_exon_and_intron = pd.read_csv('/proj/snic2021-23-365/private/TR_20230707/TR_20230707_per_gene_analysis/Csec/old_data/20230717_Csec_CpG_exons_and_introns.tsv', sep='\t', index_col=0)

    #Mbel
        #rho



Csec_rho_gene_and_flank = Csec_rho_gene_and_flank.dropna(subset=['weighted_mean_rho_gene', 'weighted_mean_rho_uflank', 'weighted_mean_rho_dflank'], how='any')

Csec_gene_and_flank = pd.merge(left=Csec_rho_gene_and_flank, right=Csec_CpG_gene_and_flank, left_on='idstring', right_on='ID', how='left')

Csec_exin = pd.merge(left=Csec_CpG_exon_and_intron, right=Csec_rho_exon_and_intron, left_on=['ID','featuretype'], right_on=['ID','featuretype'])

# generating the intron positions with Genometools has left the IDstring somewhat sparse, only denoting parent RNA.
# here i use the richer ID-string of the exons to link parent-RNA to the genebank ID

ID_dict = {}
for i in Csec_exin.loc[Csec_exin.featuretype=='exon'].ID:
    idfields = i.split(';')
    idict = {i.split('=')[0]:i.split('=')[1] for i in idfields}
    ID_dict[idict['Parent']] = idict['Dbxref']


def extract_id(idstring, idtype = 'Dbxref', ID_dict=False):
    if ID_dict == False:
        idfields = idstring.split(';')
        idict = {i.split('=')[0]:i.split('=')[1] for i in idfields}
        return idict[idtype].split(',')[0]
    else:
        idfields = idstring.split(';')
        idict = {i.split('=')[0]:i.split('=')[1] for i in idfields}
        try:
            return idict[idtype].split(',')[0]
        except KeyError:
            return ID_dict[idict['Parent']].split(',')[0]


Csec_gene_and_flank['GeneID'] = [extract_id(i) for i in Csec_gene_and_flank.ID]

Csec_exin['GeneID'] = [extract_id(i, ID_dict=ID_dict) for i in Csec_exin.ID]

# remnove superfluous columns
Csec_gene_and_flank = Csec_gene_and_flank[['scaffold', 'weighted_mean_rho_gene', 'weighted_mean_rho_uflank',
       'weighted_mean_rho_dflank', 'ID', 'gene_cpg_e',
       'gene_cpg_o', 'gene_cpg_oe', 'flank_u_cpg_e', 'flank_u_cpg_o',
       'flank_u_cpg_oe', 'flank_d_cpg_e', 'flank_d_cpg_o', 'flank_d_cpg_oe',
       'GeneID']]


# rename scaffold and rho columns to avoid issues down the line
Csec_exin.columns = ['featuretype', 'ID', 'gene_cpg_e', 'gene_cpg_o', 'gene_cpg_oe',
       'scaffold2', 'source', 'start', 'stop', 'n', 'strand', 'n2',
       'scaffold', 'weighted_mean_rho_gene', 'GeneID']

# remnove superfluous columns
Csec_exin = Csec_exin[['featuretype', 'ID', 'gene_cpg_e', 'gene_cpg_o', 'gene_cpg_oe','source', 'start', 'stop', 'n', 'strand', 'n2','scaffold', 'weighted_mean_rho_gene', 'GeneID']]


# propagate filtering to exin_data
Csec_genefilt = dict.fromkeys(Csec_gene_and_flank.GeneID)

# %%
Csec_gene_and_flank.GeneID
# Out:
# 0        GeneID:111865144
# 1        GeneID:111865148
# 2        GeneID:111865145
# 3        GeneID:111865150
# 4        GeneID:117282368
#                ...
# 12750    GeneID:111861604
# 12751    GeneID:111861606
# 12752    GeneID:111861608
# 12753    GeneID:111861600
# 12754    GeneID:111861607
# Name: GeneID, Length: 12755, dtype: object

# %%
#split into chunks and write them
chunk_n = 500
ss_split = np.array_split(list(Csec_gene_and_flank.GeneID), chunk_n)

# %%
cfiles = []
for i, k in enumerate(ss_split):
    #print(i)
    chunkname = "/home/tilman/termites/TR_20230707/TR_20230707_per_gene_analysis/csec_intron_batch_gene/ss_chunk{chunk_i}.chunk".format(chunk_i=i)
    #with open(chunkname, 'wt') as handle:
        #handle.write('\n'.join(k))
    create_and_submit_sbatch(batch=i, chunk=chunkname)
# Out:
# Submitted batch job 41233142
# Submitted batch job 41233143
# Submitted batch job 41233144
# Submitted batch job 41233145
# Submitted batch job 41233146
# Submitted batch job 41233147
# Submitted batch job 41233148
# Submitted batch job 41233149
# Submitted batch job 41233150
# Submitted batch job 41233151
# Submitted batch job 41233152
# Submitted batch job 41233153
# Submitted batch job 41233154
# Submitted batch job 41233155
# Submitted batch job 41233156
# Submitted batch job 41233157
# Submitted batch job 41233158
# Submitted batch job 41233159
# Submitted batch job 41233160
# Submitted batch job 41233161
# Submitted batch job 41233162
# Submitted batch job 41233163
# Submitted batch job 41233164
# Submitted batch job 41233165
# Submitted batch job 41233166
# Submitted batch job 41233167
# Submitted batch job 41233168
# Submitted batch job 41233169
# Submitted batch job 41233170
# Submitted batch job 41233171
# Submitted batch job 41233172
# Submitted batch job 41233173
# Submitted batch job 41233174
# Submitted batch job 41233175
# Submitted batch job 41233176
# Submitted batch job 41233177
# Submitted batch job 41233178
# Submitted batch job 41233179
# Submitted batch job 41233180
# Submitted batch job 41233181
# Submitted batch job 41233182
# Submitted batch job 41233183
# Submitted batch job 41233184
# Submitted batch job 41233185
# Submitted batch job 41233186
# Submitted batch job 41233187
# Submitted batch job 41233188
# Submitted batch job 41233189
# Submitted batch job 41233190
# Submitted batch job 41233191
# Submitted batch job 41233192
# Submitted batch job 41233193
# Submitted batch job 41233194
# Submitted batch job 41233195
# Submitted batch job 41233196
# Submitted batch job 41233197
# Submitted batch job 41233198
# Submitted batch job 41233199
# Submitted batch job 41233200
# Submitted batch job 41233201
# Submitted batch job 41233202
# Submitted batch job 41233203
# Submitted batch job 41233204
# Submitted batch job 41233205
# Submitted batch job 41233206
# Submitted batch job 41233207
# Submitted batch job 41233208
# Submitted batch job 41233209
# Submitted batch job 41233210
# Submitted batch job 41233211
# Submitted batch job 41233212
# Submitted batch job 41233213
# Submitted batch job 41233214
# Submitted batch job 41233215
# Submitted batch job 41233216
# Submitted batch job 41233217
# Submitted batch job 41233218
# Submitted batch job 41233219
# Submitted batch job 41233220
# Submitted batch job 41233221
# Submitted batch job 41233222
# Submitted batch job 41233223
# Submitted batch job 41233224
# Submitted batch job 41233225
# Submitted batch job 41233226
# Submitted batch job 41233227
# Submitted batch job 41233228
# Submitted batch job 41233229
# Submitted batch job 41233230
# Submitted batch job 41233231
# Submitted batch job 41233232
# Submitted batch job 41233233
# Submitted batch job 41233234
# Submitted batch job 41233235
# Submitted batch job 41233236
# Submitted batch job 41233237
# Submitted batch job 41233238
# Submitted batch job 41233239
# Submitted batch job 41233240
# Submitted batch job 41233241
# Submitted batch job 41233242
# Submitted batch job 41233243
# Submitted batch job 41233244
# Submitted batch job 41233245
# Submitted batch job 41233246
# Submitted batch job 41233247
# Submitted batch job 41233248
# Submitted batch job 41233249
# Submitted batch job 41233250
# Submitted batch job 41233251
# Submitted batch job 41233252
# Submitted batch job 41233253
# Submitted batch job 41233254
# Submitted batch job 41233255
# Submitted batch job 41233256
# Submitted batch job 41233257
# Submitted batch job 41233258
# Submitted batch job 41233259
# Submitted batch job 41233260
# Submitted batch job 41233261
# Submitted batch job 41233262
# Submitted batch job 41233263
# Submitted batch job 41233264
# Submitted batch job 41233265
# Submitted batch job 41233266
# Submitted batch job 41233267
# Submitted batch job 41233268
# Submitted batch job 41233269
# Submitted batch job 41233270
# Submitted batch job 41233271
# Submitted batch job 41233272
# Submitted batch job 41233273
# Submitted batch job 41233274
# Submitted batch job 41233275
# Submitted batch job 41233276
# Submitted batch job 41233277
# Submitted batch job 41233278
# Submitted batch job 41233279
# Submitted batch job 41233280
# Submitted batch job 41233281
# Submitted batch job 41233282
# Submitted batch job 41233283
# Submitted batch job 41233284
# Submitted batch job 41233285
# Submitted batch job 41233286
# Submitted batch job 41233287
# Submitted batch job 41233288
# Submitted batch job 41233289
# Submitted batch job 41233290
# Submitted batch job 41233291
# Submitted batch job 41233292
# Submitted batch job 41233293
# Submitted batch job 41233294
# Submitted batch job 41233295
# Submitted batch job 41233296
# Submitted batch job 41233297
# Submitted batch job 41233298
# Submitted batch job 41233299
# Submitted batch job 41233300
# Submitted batch job 41233301
# Submitted batch job 41233302
# Submitted batch job 41233303
# Submitted batch job 41233304
# Submitted batch job 41233305
# Submitted batch job 41233306
# Submitted batch job 41233307
# Submitted batch job 41233308
# Submitted batch job 41233309
# Submitted batch job 41233310
# Submitted batch job 41233311
# Submitted batch job 41233312
# Submitted batch job 41233313
# Submitted batch job 41233314
# Submitted batch job 41233315
# Submitted batch job 41233316
# Submitted batch job 41233317
# Submitted batch job 41233318
# Submitted batch job 41233319
# Submitted batch job 41233320
# Submitted batch job 41233321
# Submitted batch job 41233322
# Submitted batch job 41233323
# Submitted batch job 41233324
# Submitted batch job 41233325
# Submitted batch job 41233326
# Submitted batch job 41233327
# Submitted batch job 41233328
# Submitted batch job 41233329
# Submitted batch job 41233330
# Submitted batch job 41233331
# Submitted batch job 41233332
# Submitted batch job 41233333
# Submitted batch job 41233334
# Submitted batch job 41233335
# Submitted batch job 41233336
# Submitted batch job 41233337
# Submitted batch job 41233338
# Submitted batch job 41233339
# Submitted batch job 41233340
# Submitted batch job 41233341
# Submitted batch job 41233342
# Submitted batch job 41233343
# Submitted batch job 41233344
# Submitted batch job 41233345
# Submitted batch job 41233346
# Submitted batch job 41233347
# Submitted batch job 41233348
# Submitted batch job 41233349
# Submitted batch job 41233350
# Submitted batch job 41233351
# Submitted batch job 41233352
# Submitted batch job 41233353
# Submitted batch job 41233354
# Submitted batch job 41233355
# Submitted batch job 41233356
# Submitted batch job 41233357
# Submitted batch job 41233358
# Submitted batch job 41233359
# Submitted batch job 41233360
# Submitted batch job 41233361
# Submitted batch job 41233362
# Submitted batch job 41233363
# Submitted batch job 41233364
# Submitted batch job 41233365
# Submitted batch job 41233366
# Submitted batch job 41233367
# Submitted batch job 41233368
# Submitted batch job 41233369
# Submitted batch job 41233370
# Submitted batch job 41233371
# Submitted batch job 41233372
# Submitted batch job 41233373
# Submitted batch job 41233374
# Submitted batch job 41233375
# Submitted batch job 41233376
# Submitted batch job 41233377
# Submitted batch job 41233378
# Submitted batch job 41233379
# Submitted batch job 41233380
# Submitted batch job 41233381
# Submitted batch job 41233382
# Submitted batch job 41233383
# Submitted batch job 41233384
# Submitted batch job 41233385
# Submitted batch job 41233386
# Submitted batch job 41233387
# Submitted batch job 41233388
# Submitted batch job 41233389
# Submitted batch job 41233390
# Submitted batch job 41233391
# Submitted batch job 41233392
# Submitted batch job 41233393
# Submitted batch job 41233394
# Submitted batch job 41233395
# Submitted batch job 41233396
# Submitted batch job 41233397
# Submitted batch job 41233398
# Submitted batch job 41233399
# Submitted batch job 41233400
# Submitted batch job 41233401
# Submitted batch job 41233402
# Submitted batch job 41233403
# Submitted batch job 41233404
# Submitted batch job 41233405
# Submitted batch job 41233406
# Submitted batch job 41233407
# Submitted batch job 41233408
# Submitted batch job 41233409
# Submitted batch job 41233410
# Submitted batch job 41233411
# Submitted batch job 41233412
# Submitted batch job 41233413
# Submitted batch job 41233414
# Submitted batch job 41233415
# Submitted batch job 41233416
# Submitted batch job 41233417
# Submitted batch job 41233418
# Submitted batch job 41233419
# Submitted batch job 41233420
# Submitted batch job 41233421
# Submitted batch job 41233422
# Submitted batch job 41233423
# Submitted batch job 41233424
# Submitted batch job 41233425
# Submitted batch job 41233426
# Submitted batch job 41233427
# Submitted batch job 41233428
# Submitted batch job 41233429
# Submitted batch job 41233430
# Submitted batch job 41233431
# Submitted batch job 41233432
# Submitted batch job 41233433
# Submitted batch job 41233434
# Submitted batch job 41233435
# Submitted batch job 41233436
# Submitted batch job 41233437
# Submitted batch job 41233438
# Submitted batch job 41233439
# Submitted batch job 41233440
# Submitted batch job 41233441
# Submitted batch job 41233442
# Submitted batch job 41233443
# Submitted batch job 41233444
# Submitted batch job 41233445
# Submitted batch job 41233446
# Submitted batch job 41233447
# Submitted batch job 41233448
# Submitted batch job 41233449
# Submitted batch job 41233450
# Submitted batch job 41233451
# Submitted batch job 41233452
# Submitted batch job 41233453
# Submitted batch job 41233454
# Submitted batch job 41233455
# Submitted batch job 41233456
# Submitted batch job 41233457
# Submitted batch job 41233458
# Submitted batch job 41233459
# Submitted batch job 41233460
# Submitted batch job 41233461
# Submitted batch job 41233462
# Submitted batch job 41233463
# Submitted batch job 41233464
# Submitted batch job 41233465
# Submitted batch job 41233466
# Submitted batch job 41233467
# Submitted batch job 41233468
# Submitted batch job 41233469
# Submitted batch job 41233470
# Submitted batch job 41233471
# Submitted batch job 41233472
# Submitted batch job 41233473
# Submitted batch job 41233474
# Submitted batch job 41233475
# Submitted batch job 41233476
# Submitted batch job 41233477
# Submitted batch job 41233478
# Submitted batch job 41233479
# Submitted batch job 41233480
# Submitted batch job 41233481
# Submitted batch job 41233482
# Submitted batch job 41233483
# Submitted batch job 41233484
# Submitted batch job 41233485
# Submitted batch job 41233486
# Submitted batch job 41233487
# Submitted batch job 41233488
# Submitted batch job 41233489
# Submitted batch job 41233490
# Submitted batch job 41233491
# Submitted batch job 41233492
# Submitted batch job 41233493
# Submitted batch job 41233494
# Submitted batch job 41233495
# Submitted batch job 41233496
# Submitted batch job 41233497
# Submitted batch job 41233498
# Submitted batch job 41233499
# Submitted batch job 41233500
# Submitted batch job 41233501
# Submitted batch job 41233502
# Submitted batch job 41233503
# Submitted batch job 41233504
# Submitted batch job 41233505
# Submitted batch job 41233506
# Submitted batch job 41233507
# Submitted batch job 41233508
# Submitted batch job 41233509
# Submitted batch job 41233510
# Submitted batch job 41233511
# Submitted batch job 41233512
# Submitted batch job 41233513
# Submitted batch job 41233514
# Submitted batch job 41233515
# Submitted batch job 41233516
# Submitted batch job 41233517
# Submitted batch job 41233518
# Submitted batch job 41233519
# Submitted batch job 41233520
# Submitted batch job 41233521
# Submitted batch job 41233522
# Submitted batch job 41233523
# Submitted batch job 41233524
# Submitted batch job 41233525
# Submitted batch job 41233526
# Submitted batch job 41233527
# Submitted batch job 41233528
# Submitted batch job 41233529
# Submitted batch job 41233530
# Submitted batch job 41233531
# Submitted batch job 41233532
# Submitted batch job 41233533
# Submitted batch job 41233534
# Submitted batch job 41233535
# Submitted batch job 41233536
# Submitted batch job 41233537
# Submitted batch job 41233538
# Submitted batch job 41233539
# Submitted batch job 41233540
# Submitted batch job 41233541
# Submitted batch job 41233542
# Submitted batch job 41233543
# Submitted batch job 41233544
# Submitted batch job 41233545
# Submitted batch job 41233546
# Submitted batch job 41233547
# Submitted batch job 41233548
# Submitted batch job 41233549
# Submitted batch job 41233550
# Submitted batch job 41233551
# Submitted batch job 41233552
# Submitted batch job 41233553
# Submitted batch job 41233554
# Submitted batch job 41233555
# Submitted batch job 41233556
# Submitted batch job 41233557
# Submitted batch job 41233558
# Submitted batch job 41233559
# Submitted batch job 41233560
# Submitted batch job 41233561
# Submitted batch job 41233562
# Submitted batch job 41233563
# Submitted batch job 41233564
# Submitted batch job 41233565
# Submitted batch job 41233566
# Submitted batch job 41233567
# Submitted batch job 41233568
# Submitted batch job 41233569
# Submitted batch job 41233570
# Submitted batch job 41233571
# Submitted batch job 41233572
# Submitted batch job 41233573
# Submitted batch job 41233574
# Submitted batch job 41233575
# Submitted batch job 41233576
# Submitted batch job 41233577
# Submitted batch job 41233578
# Submitted batch job 41233579
# Submitted batch job 41233580
# Submitted batch job 41233581
# Submitted batch job 41233582
# Submitted batch job 41233583
# Submitted batch job 41233584
# Submitted batch job 41233585
# Submitted batch job 41233586
# Submitted batch job 41233587
# Submitted batch job 41233588
# Submitted batch job 41233589
# Submitted batch job 41233590
# Submitted batch job 41233591
# Submitted batch job 41233592
# Submitted batch job 41233593
# Submitted batch job 41233594
# Submitted batch job 41233595
# Submitted batch job 41233596
# Submitted batch job 41233597
# Submitted batch job 41233598
# Submitted batch job 41233599
# Submitted batch job 41233600
# Submitted batch job 41233601
# Submitted batch job 41233602
# Submitted batch job 41233603
# Submitted batch job 41233604
# Submitted batch job 41233605
# Submitted batch job 41233606
# Submitted batch job 41233607
# Submitted batch job 41233608
# Submitted batch job 41233609
# Submitted batch job 41233610
# Submitted batch job 41233611
# Submitted batch job 41233612
# Submitted batch job 41233613
# Submitted batch job 41233614
# Submitted batch job 41233615
# Submitted batch job 41233616
# Submitted batch job 41233617
# Submitted batch job 41233618
# Submitted batch job 41233619
# Submitted batch job 41233620
# Submitted batch job 41233621
# Submitted batch job 41233622
# Submitted batch job 41233623
# Submitted batch job 41233624
# Submitted batch job 41233625
# Submitted batch job 41233626
# Submitted batch job 41233627
# Submitted batch job 41233628
# Submitted batch job 41233629
# Submitted batch job 41233630
# Submitted batch job 41233631
# Submitted batch job 41233632
# Submitted batch job 41233633
# Submitted batch job 41233634
# Submitted batch job 41233635
# Submitted batch job 41233636
# Submitted batch job 41233637
# Submitted batch job 41233638
# Submitted batch job 41233639
# Submitted batch job 41233640
# Submitted batch job 41233641

# %%
! mkdir csec_intron_batch_gene

# %%
intron_mean_dfs = []
for i in os.listdir('csec_intron_batch_gene'):
    if i.endswith('Csec_intron_weighted_mean_rho.csv'):
        h = pd.read_csv(os.path.join('csec_intron_batch_gene', i))
        intron_mean_dfs.append(h)

# %%
pd.concat(intron_mean_dfs).to_csv('20230920_Csec_intron_mean_rho.csv')
